# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Fix: Keep the URL on a single line or use proper string concatenation
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv"

wine_data_red = pd.read_csv(url, sep=';')

# %%
print("First few rows of the Wine Quality Data Set for red variants:")
print(wine_data_red.head())
# Out:
# First few rows of the Wine Quality Data Set for red variants:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# ...

# %%
print("\nSummary Statistics:")
print(wine_data_red.describe())
# Out:
# Summary Statistics:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
print("\nMissing Values:")
print(wine_data_red.isnull().sum())
# Out:
# Missing Values:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='quality', data=wine_data_red, palette='viridis')
plt.title('Distribution of Wine Quality for Red Variants')
plt.xlabel('Quality')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\SHOBANA G\AppData\Local\Temp\ipykernel_3608\3500652307.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='quality', data=wine_data_red, palette='viridis')

# %%
correlation_matrix_red = wine_data_red.corr()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix_red, annot=True, cmap='coolwarm',
fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix for Red Variants')
plt.show()

# %%
# First, import the necessary libraries if not already imported
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the wine dataset (adjust the path as needed)
# Fix: Use raw string (r prefix) or double backslashes or forward slashes for file paths
wine_df = pd.read_csv(r"C:\Users\SHOBANA G\Downloads\WineQT.csv")  # Using raw string
# Alternative fixes:
# wine_df = pd.read_csv("C:\\Users\\SHOBANA G\\Downloads\\WineQT.csv")  # Using double backslashes
# wine_df = pd.read_csv("C:/Users/SHOBANA G/Downloads/WineQT.csv")  # Using forward slashes

# Now create the pair plot with the defined dataframe
selected_features_red = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 
 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol', 'quality'] 

sns.pairplot(wine_df[selected_features_red], diag_kind='kde') 
plt.suptitle("Pair Plot of Selected Features for Red Variants", y=1.02)
# Out:
# Text(0.5, 1.02, 'Pair Plot of Selected Features for Red Variants')

# %%
plt.figure(figsize=(12, 8)) 
for i, feature in enumerate(selected_features_red[:-1]): 
    plt.subplot(3, 4, i + 1) 
    sns.boxplot(x='quality', y=feature, data=wine_q, palette='viridis') 
    plt.title(f'Box Plot of {feature} by Wine Quality') 
    plt.xlabel('Quality') 
    plt.ylabel(feature) 
plt.tight_layout() 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 4
#       2 for i, feature in enumerate(selected_features_red[:-1]):
#       3     plt.subplot(3, 4, i + 1)
# ----> 4     sns.boxplot(x='quality', y=feature, data=wine_q, palette='viridis')
#       5     plt.title(f'Box Plot of {feature} by Wine Quality')
#       6     plt.xlabel('Quality')
#
# NameError: name 'wine_q' is not defined
