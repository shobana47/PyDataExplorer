# %%
import pandas as pd 
import folium 
from folium import Choropleth, Circle, Marker 
from folium.plugins import HeatMap, MarkerCluster

# %%
data = folium.Map(location=[42.32,-71.0589], tiles='openstreetmap', 
zoom_start=10) 
data
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
# Import pandas library first
import pandas as pd

# Then proceed with your code
# Fix the file path by using raw strings (r prefix)
crimes = pd.read_csv(r"C:\Users\SHOBANA G\Documents\EDA_python\DATASETS\crime_data.csv") 

# Check the actual column names in your DataFrame
print("Column names in the DataFrame:")
print(crimes.columns.tolist())

# Dropna before filtering
crimes.dropna(inplace=True)

# Print the first few rows to verify the data
print("\nFirst 5 rows of the DataFrame:")
print(crimes.head())
# Out:
# Column names in the DataFrame:
# ['Disposition', 'OffenderStatus', 'Offender_Race', 'Offender_Gender', 'Offender_Age', 'PersonType', 'Victim_Race', 'Victim_Gender', 'Victim_Age', 'Victim_Fatal_Status', 'Report Type', 'Category']
#
# First 5 rows of the DataFrame:
#   Disposition OffenderStatus Offender_Race Offender_Gender  Offender_Age  \
# 0      CLOSED       ARRESTED         BLACK            MALE          30.0
# 1      CLOSED       ARRESTED         BLACK            MALE          30.0
# 2      CLOSED       ARRESTED         BLACK            MALE          30.0
# 3      CLOSED       ARRESTED         BLACK            MALE          30.0
# 4      CLOSED       ARRESTED         BLACK            MALE          30.0
#
#   PersonType Victim_Race Victim_Gender  Victim_Age Victim_Fatal_Status  \
# 0     VICTIM       BLACK        FEMALE        29.0           Non-fatal
# 1     VICTIM       BLACK        FEMALE        29.0           Non-fatal
# ...

# %%
import folium

# Initialize the map object
m_2 = folium.Map(location=[42.32, -71.0589], tiles="cartodbpositron", zoom_start=12)

# Example DataFrame (replace with your actual data)
import pandas as pd
data = {'Lat': [42.35, 42.36], 'Long': [-71.06, -71.07]}
daytime_robberies = pd.DataFrame(data)

# Add markers to the map
for idx, row in daytime_robberies.iterrows():
    folium.Marker([row['Lat'], row['Long']]).add_to(m_2)

# Display the map
m_2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...
